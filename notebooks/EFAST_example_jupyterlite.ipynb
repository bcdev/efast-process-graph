# %%
from pathlib import Path
import time
from datetime import datetime

# %%
# %pip install openeo geopandas shapely matplotlib xarray numpy pandas netcdf4 jupytergis-lite
# Out:
# Requirement already satisfied: openeo in /home/hannes/micromamba/envs/efast-process-graph/lib/python3.12/site-packages (0.46.0)
# Requirement already satisfied: geopandas in /home/hannes/micromamba/envs/efast-process-graph/lib/python3.12/site-packages (1.1.1)
# Requirement already satisfied: shapely in /home/hannes/micromamba/envs/efast-process-graph/lib/python3.12/site-packages (2.1.2)
# Requirement already satisfied: matplotlib in /home/hannes/micromamba/envs/efast-process-graph/lib/python3.12/site-packages (3.10.8)
# Requirement already satisfied: xarray in /home/hannes/micromamba/envs/efast-process-graph/lib/python3.12/site-packages (2025.1.1)
# Requirement already satisfied: numpy in /home/hannes/micromamba/envs/efast-process-graph/lib/python3.12/site-packages (2.3.5)
# Requirement already satisfied: pandas in /home/hannes/micromamba/envs/efast-process-graph/lib/python3.12/site-packages (2.3.3)
# Requirement already satisfied: netcdf4 in /home/hannes/micromamba/envs/efast-process-graph/lib/python3.12/site-packages (1.7.3)
# Requirement already satisfied: jupytergis-lite in /home/hannes/micromamba/envs/efast-process-graph/lib/python3.12/site-packages (0.11.1)
# Requirement already satisfied: requests>=2.26.0 in /home/hannes/micromamba/envs/efast-process-graph/lib/python3.12/site-packages (from openeo) (2.32.5)
# Requirement already satisfied: urllib3>=1.9.0 in /home/hannes/micromamba/envs/efast-process-graph/lib/python3.12/site-packages (from openeo) (2.6.2)
# Requirement already satisfied: pystac>=1.5.0 in /home/hannes/micromamba/envs/efast-process-graph/lib/python3.12/site-packages (from openeo) (1.14.1)
# Requirement already satisfied: deprecated>=1.2.12 in /home/hannes/micromamba/envs/efast-process-graph/lib/python3.12/site-packages (from openeo) (1.3.1)
# Requirement already satisfied: packaging>=23.2 in /home/hannes/micromamba/envs/efast-process-graph/lib/python3.12/site-packages (from xarray) (25.0)
# Requirement already satisfied: contourpy>=1.0.1 in /home/hannes/micromamba/envs/efast-process-graph/lib/python3.12/site-packages (from matplotlib) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /home/hannes/micromamba/envs/efast-process-graph/lib/python3.12/site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /home/hannes/micromamba/envs/efast-process-graph/lib/python3.12/site-packages (from matplotlib) (4.61.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /home/hannes/micromamba/envs/efast-process-graph/lib/python3.12/site-packages (from matplotlib) (1.4.9)
# Requirement already satisfied: pillow>=8 in /home/hannes/micromamba/envs/efast-process-graph/lib/python3.12/site-packages (from matplotlib) (12.0.0)
# Requirement already satisfied: pyparsing>=3 in /home/hannes/micromamba/envs/efast-process-graph/lib/python3.12/site-packages (from matplotlib) (3.2.5)
# Requirement already satisfied: python-dateutil>=2.7 in /home/hannes/micromamba/envs/efast-process-graph/lib/python3.12/site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /home/hannes/micromamba/envs/efast-process-graph/lib/python3.12/site-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /home/hannes/micromamba/envs/efast-process-graph/lib/python3.12/site-packages (from pandas) (2025.3)
# Requirement already satisfied: cftime in /home/hannes/micromamba/envs/efast-process-graph/lib/python3.12/site-packages (from netcdf4) (1.6.4)
# Requirement already satisfied: certifi in /home/hannes/micromamba/envs/efast-process-graph/lib/python3.12/site-packages (from netcdf4) (2025.11.12)
# Requirement already satisfied: jupytergis-core==0.11.1 in /home/hannes/micromamba/envs/efast-process-graph/lib/python3.12/site-packages (from jupytergis-lite) (0.11.1)
# Requirement already satisfied: jupytergis-lab==0.11.1 in /home/hannes/micromamba/envs/efast-process-graph/lib/python3.12/site-packages (from jupytergis-lite) (0.11.1)
# Requirement already satisfied: my-jupyter-shared-drive>=0.2.2 in /home/hannes/micromamba/envs/efast-process-graph/lib/python3.12/site-packages (from jupytergis-lite) (0.2.2)
# Requirement already satisfied: jupyter-ydoc<4,>=2 in /home/hannes/micromamba/envs/efast-process-graph/lib/python3.12/site-packages (from jupytergis-core==0.11.1->jupytergis-lite) (3.3.4)
# Requirement already satisfied: comm<0.2.0,>=0.1.2 in /home/hannes/micromamba/envs/efast-process-graph/lib/python3.12/site-packages (from jupytergis-lab==0.11.1->jupytergis-lite) (0.1.4)
# Requirement already satisfied: pydantic<3,>=2 in /home/hannes/micromamba/envs/efast-process-graph/lib/python3.12/site-packages (from jupytergis-lab==0.11.1->jupytergis-lite) (2.12.5)
# Requirement already satisfied: sidecar>=0.7.0 in /home/hannes/micromamba/envs/efast-process-graph/lib/python3.12/site-packages (from jupytergis-lab==0.11.1->jupytergis-lite) (0.8.0)
# Requirement already satisfied: yjs-widgets<0.5,>=0.4 in /home/hannes/micromamba/envs/efast-process-graph/lib/python3.12/site-packages (from jupytergis-lab==0.11.1->jupytergis-lite) (0.4.0)
# Requirement already satisfied: ypywidgets<0.10.0,>=0.9.0 in /home/hannes/micromamba/envs/efast-process-graph/lib/python3.12/site-packages (from jupytergis-lab==0.11.1->jupytergis-lite) (0.9.7)
# Requirement already satisfied: traitlets>=4 in /home/hannes/micromamba/envs/efast-process-graph/lib/python3.12/site-packages (from comm<0.2.0,>=0.1.2->jupytergis-lab==0.11.1->jupytergis-lite) (5.14.3)
# Requirement already satisfied: pycrdt<0.13.0,>=0.10.1 in /home/hannes/micromamba/envs/efast-process-graph/lib/python3.12/site-packages (from jupyter-ydoc<4,>=2->jupytergis-core==0.11.1->jupytergis-lite) (0.12.45)
# Requirement already satisfied: anyio<5.0.0,>=4.4.0 in /home/hannes/micromamba/envs/efast-process-graph/lib/python3.12/site-packages (from pycrdt<0.13.0,>=0.10.1->jupyter-ydoc<4,>=2->jupytergis-core==0.11.1->jupytergis-lite) (4.12.0)
# Requirement already satisfied: idna>=2.8 in /home/hannes/micromamba/envs/efast-process-graph/lib/python3.12/site-packages (from anyio<5.0.0,>=4.4.0->pycrdt<0.13.0,>=0.10.1->jupyter-ydoc<4,>=2->jupytergis-core==0.11.1->jupytergis-lite) (3.11)
# Requirement already satisfied: typing_extensions>=4.5 in /home/hannes/micromamba/envs/efast-process-graph/lib/python3.12/site-packages (from anyio<5.0.0,>=4.4.0->pycrdt<0.13.0,>=0.10.1->jupyter-ydoc<4,>=2->jupytergis-core==0.11.1->jupytergis-lite) (4.15.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /home/hannes/micromamba/envs/efast-process-graph/lib/python3.12/site-packages (from pydantic<3,>=2->jupytergis-lab==0.11.1->jupytergis-lite) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in /home/hannes/micromamba/envs/efast-process-graph/lib/python3.12/site-packages (from pydantic<3,>=2->jupytergis-lab==0.11.1->jupytergis-lite) (2.41.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in /home/hannes/micromamba/envs/efast-process-graph/lib/python3.12/site-packages (from pydantic<3,>=2->jupytergis-lab==0.11.1->jupytergis-lite) (0.4.2)
# Requirement already satisfied: reacttrs<0.3.0,>=0.2.1 in /home/hannes/micromamba/envs/efast-process-graph/lib/python3.12/site-packages (from ypywidgets<0.10.0,>=0.9.0->jupytergis-lab==0.11.1->jupytergis-lite) (0.2.1)
# Requirement already satisfied: wrapt<3,>=1.10 in /home/hannes/micromamba/envs/efast-process-graph/lib/python3.12/site-packages (from deprecated>=1.2.12->openeo) (1.17.3)
# Requirement already satisfied: six>=1.5 in /home/hannes/micromamba/envs/efast-process-graph/lib/python3.12/site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /home/hannes/micromamba/envs/efast-process-graph/lib/python3.12/site-packages (from requests>=2.26.0->openeo) (3.4.4)
# Requirement already satisfied: ipywidgets<9,>=8 in /home/hannes/micromamba/envs/efast-process-graph/lib/python3.12/site-packages (from sidecar>=0.7.0->jupytergis-lab==0.11.1->jupytergis-lite) (8.1.8)
# Requirement already satisfied: ipython>=6.1.0 in /home/hannes/micromamba/envs/efast-process-graph/lib/python3.12/site-packages (from ipywidgets<9,>=8->sidecar>=0.7.0->jupytergis-lab==0.11.1->jupytergis-lite) (9.8.0)
# Requirement already satisfied: widgetsnbextension~=4.0.14 in /home/hannes/micromamba/envs/efast-process-graph/lib/python3.12/site-packages (from ipywidgets<9,>=8->sidecar>=0.7.0->jupytergis-lab==0.11.1->jupytergis-lite) (4.0.15)
# Requirement already satisfied: jupyterlab_widgets~=3.0.15 in /home/hannes/micromamba/envs/efast-process-graph/lib/python3.12/site-packages (from ipywidgets<9,>=8->sidecar>=0.7.0->jupytergis-lab==0.11.1->jupytergis-lite) (3.0.16)
# Requirement already satisfied: decorator>=4.3.2 in /home/hannes/micromamba/envs/efast-process-graph/lib/python3.12/site-packages (from ipython>=6.1.0->ipywidgets<9,>=8->sidecar>=0.7.0->jupytergis-lab==0.11.1->jupytergis-lite) (5.2.1)
# Requirement already satisfied: ipython-pygments-lexers>=1.0.0 in /home/hannes/micromamba/envs/efast-process-graph/lib/python3.12/site-packages (from ipython>=6.1.0->ipywidgets<9,>=8->sidecar>=0.7.0->jupytergis-lab==0.11.1->jupytergis-lite) (1.1.1)
# Requirement already satisfied: jedi>=0.18.1 in /home/hannes/micromamba/envs/efast-process-graph/lib/python3.12/site-packages (from ipython>=6.1.0->ipywidgets<9,>=8->sidecar>=0.7.0->jupytergis-lab==0.11.1->jupytergis-lite) (0.19.2)
# Requirement already satisfied: matplotlib-inline>=0.1.5 in /home/hannes/micromamba/envs/efast-process-graph/lib/python3.12/site-packages (from ipython>=6.1.0->ipywidgets<9,>=8->sidecar>=0.7.0->jupytergis-lab==0.11.1->jupytergis-lite) (0.2.1)
# Requirement already satisfied: pexpect>4.3 in /home/hannes/micromamba/envs/efast-process-graph/lib/python3.12/site-packages (from ipython>=6.1.0->ipywidgets<9,>=8->sidecar>=0.7.0->jupytergis-lab==0.11.1->jupytergis-lite) (4.9.0)
# Requirement already satisfied: prompt_toolkit<3.1.0,>=3.0.41 in /home/hannes/micromamba/envs/efast-process-graph/lib/python3.12/site-packages (from ipython>=6.1.0->ipywidgets<9,>=8->sidecar>=0.7.0->jupytergis-lab==0.11.1->jupytergis-lite) (3.0.52)
# Requirement already satisfied: pygments>=2.11.0 in /home/hannes/micromamba/envs/efast-process-graph/lib/python3.12/site-packages (from ipython>=6.1.0->ipywidgets<9,>=8->sidecar>=0.7.0->jupytergis-lab==0.11.1->jupytergis-lite) (2.19.2)
# Requirement already satisfied: stack_data>=0.6.0 in /home/hannes/micromamba/envs/efast-process-graph/lib/python3.12/site-packages (from ipython>=6.1.0->ipywidgets<9,>=8->sidecar>=0.7.0->jupytergis-lab==0.11.1->jupytergis-lite) (0.6.3)
# Requirement already satisfied: wcwidth in /home/hannes/micromamba/envs/efast-process-graph/lib/python3.12/site-packages (from prompt_toolkit<3.1.0,>=3.0.41->ipython>=6.1.0->ipywidgets<9,>=8->sidecar>=0.7.0->jupytergis-lab==0.11.1->jupytergis-lite) (0.2.14)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in /home/hannes/micromamba/envs/efast-process-graph/lib/python3.12/site-packages (from jedi>=0.18.1->ipython>=6.1.0->ipywidgets<9,>=8->sidecar>=0.7.0->jupytergis-lab==0.11.1->jupytergis-lite) (0.8.5)
# Requirement already satisfied: ptyprocess>=0.5 in /home/hannes/micromamba/envs/efast-process-graph/lib/python3.12/site-packages (from pexpect>4.3->ipython>=6.1.0->ipywidgets<9,>=8->sidecar>=0.7.0->jupytergis-lab==0.11.1->jupytergis-lite) (0.7.0)
# Requirement already satisfied: executing>=1.2.0 in /home/hannes/micromamba/envs/efast-process-graph/lib/python3.12/site-packages (from stack_data>=0.6.0->ipython>=6.1.0->ipywidgets<9,>=8->sidecar>=0.7.0->jupytergis-lab==0.11.1->jupytergis-lite) (2.2.1)
# Requirement already satisfied: asttokens>=2.1.0 in /home/hannes/micromamba/envs/efast-process-graph/lib/python3.12/site-packages (from stack_data>=0.6.0->ipython>=6.1.0->ipywidgets<9,>=8->sidecar>=0.7.0->jupytergis-lab==0.11.1->jupytergis-lite) (3.0.1)
# Requirement already satisfied: pure_eval in /home/hannes/micromamba/envs/efast-process-graph/lib/python3.12/site-packages (from stack_data>=0.6.0->ipython>=6.1.0->ipywidgets<9,>=8->sidecar>=0.7.0->jupytergis-lab==0.11.1->jupytergis-lite) (0.2.3)
# Note: you may need to restart the kernel to use updated packages.

# %%
import openeo
import geopandas as gpd
import shapely
import matplotlib.pyplot as plt
import matplotlib.animation as animation
import xarray as xr
import numpy as np
import pandas as pd
from IPython.display import Image, display, HTML
import jupytergis

# %% [markdown]
# # EFAST
#
# The *Efficient Fusion Algorithm Across Spatio-Temporal Scales* (EFAST) \[1\] is a method to create time-series with a fine resolution in space and time from a fine spatial but coarse temporal resolution source (Sentinel-2) and a coarse temporal but fine spatial resolution source (Sentinel-3).
# In comparison to other methods, EFAST aims to achieve results outperforming single-source interpolation without paying the computational cost of other methods leveraging spatial context.
#
# DHI-GRAS has published a Python implementation of the algorithm \[2\]. In the context of the ESA funded APEx initiative \[3\], the algorithm
# has been ported to OpenEO. This notebook showcases the OpenEO implementation and its parameters.
#
#
# \[1\]: Senty, Paul, Radoslaw Guzinski, Kenneth Grogan, et al. “Fast Fusion of Sentinel-2 and Sentinel-3 Time Series over Rangelands.” Remote Sensing 16, no. 11 (2024): 1833.
#
# \[2\]: https://github.com/DHI-GRAS/efast
#
# \[3\]: https://apex.esa.int/
#
# \[4\]: https://github.com/bcdev/efast-process-graph/

# %%
connection = openeo.connect("https://openeo.dataspace.copernicus.eu").authenticate_oidc()
# Out:
# Authenticated using refresh token.

# %%
PROCESS_GRAPH_URL = "https://raw.githubusercontent.com/bcdev/efast-process-graph/refs/heads/main/process_graph.json"

# %%
SKIP_EXECUTION = False # If True do not rerun process graph / download (expects that the output directory is already filled)
WAIT_FOR_COMPLETION = True # Set to False to not block after submitting openeo jobs

# %% [markdown]
# ## Parameters
#
# EFAST transforms the two input time series of Sentinel-2 and Sentinel-3 observations into a target time series.
# The input time series are defined by the familiar `temporal_extent` parameter and the availability of data for each sensor.
# The target time series is defined by a separate parameter `temporal_extent_target`, together with the target interval `interval_days`.
# `temporal_extent_target` should cover a shorter interval, fully contained within `temporal_extent`, because EFAST considers temporal context both before and after the target observation when computing its result, with a standard deviation of 20 days. This allows for some temporal context for the first and last time step of the target time series. This parameter is optional. If it is not provided, the entire temporal extent of the input (`temporal_extent`) is reused to define the target time series.
#
# EFAST uses bands with closely aligned central wavelengths to interpolate between Sentinel-2 observations. The process graph takes the parameters
# `s2_data_bands` and `s3_data_bands` to define which bands should be computed. Users must take care to specify band names that match in central wavelength and to specify bands of similar wavelength in the same position in the list.
#
# For example, to compute a RGB image, we can use the blue, green, and red bands of both the Sentinel-2 and Sentinel-3 collections:
#
# - `s2_data_bands=["B02", "B03", "B04"]` with central wavelengths 490nm (blue), 560nm (green) and 665nm (red)
# - `s3_data_bands=["Syn_Oa04_reflectance", "Syn_Oa06_reflectance", "Syn_Oa08_reflectance"]` with central wavelengths 490nm, 560nm and 665nm
#
# And to compute the NDVI, we can use
#
# - `s2_data_bands=["B04","B8A"]` with central wavelengths 665nm (red) and 865nm (NIR)
# - `s3_data_bands=["Syn_Oa08_reflectance", "Syn_Oa17_reflectance"]`, with central wavelengths 490nm and 865nm.
#
# The EFAST UDP actually provides a parameter, `output_ndvi`, to return the NDVI as the single output band instead of the band values.
# When setting this option to True, make sure that the correct bands are included, otherwise the process will fail.
#
# In total, we set the following parameters:
#
# - `s2_data_bands` bands of the `SENTINEL2_L2A` collection. Make sure to align bands with `s3_data_bands`
# - `s3_data_bands` bands of the `SENTINEL3_SYN_L2_SYN` collection. Make sure to align the bands with `s2_data_bands`
# - `temporal_extent` temporal extent of the *inputs*
# - `temporal_extent_target` (optional, default `temporal_extent`) temporal extent of the *output*. Should be fully covered by `temporal_extent`.
# - `spatial_extent` the spatial extent of inputs and outputs.
# - `interval_days` interval of the output time series (days)
# - `output_ndvi` (optional, default `False`) whether to output NDVI instead of bands. If set, `s2_data_bands` must be `["B04","B8A"]` and `s3_data_bands` must be `["Syn_Oa08_reflectance", "Syn_Oa17_reflectance"]`
#
# For a first example, we set the RGB bands:

# %%
s2_data_bands = ["B02", "B03", "B04"]
s3_data_bands=["Syn_Oa04_reflectance", "Syn_Oa06_reflectance", "Syn_Oa08_reflectance"]
fused_band_names = [] # optional
temporal_extent = ["2023-09-01", "2023-10-01"]
temporal_extent_target = ["2023-09-03", "2023-09-29"]
spatial_extent={
    "west": -15.9,
    "south": 16.07,
    "east": -15.7,
    "north": 16.27,
}
interval_days = 10

# %%
w = spatial_extent["west"]
e = spatial_extent["east"]
s = spatial_extent["south"]
n = spatial_extent["north"]

polygon = shapely.box(w,s,e,n)
gdf = gpd.GeoDataFrame(geometry=[polygon], crs="EPSG:4326")

# %%
doc = jupytergis.GISDocument(latitude=n, longitude=w, zoom=7)
doc.add_raster_layer("https://tile.openstreetmap.org/{z}/{x}/{y}.png", name="OSM")
doc.add_geojson_layer(data=gdf.to_geo_dict(), name="AOI")
doc

# %% [markdown]
# ## Defining the process graph
#
# EFAST is defined as a UDP, so we can run it using `datacube_from_process`, providing the name (`efast`) and a URL to the process graph JSON as `namespace`. All the other parameters belong to the EFAST UDP, as described above.

# %%
cube = connection.datacube_from_process(
    "efast",
    namespace=PROCESS_GRAPH_URL,
    s2_data_bands=s2_data_bands,
    s3_data_bands=s3_data_bands,
    temporal_extent=temporal_extent,
    temporal_extent_target=temporal_extent_target,
    spatial_extent=spatial_extent,
    interval_days=interval_days,
)
print(cube.to_json())
# Out:
# {
#   "process_graph": {
#     "efast1": {
#       "process_id": "efast",
#       "arguments": {
#         "interval_days": 10,
#         "s2_data_bands": [
#           "B02",
#           "B03",
#           "B04"
#         ],
#         "s3_data_bands": [
#           "Syn_Oa04_reflectance",
#           "Syn_Oa06_reflectance",
#           "Syn_Oa08_reflectance"
#         ],
#         "spatial_extent": {
#           "west": -15.9,
#           "south": 16.07,
#           "east": -15.7,
#           "north": 16.27
#         },
#         "temporal_extent": [
#           "2023-09-01",
#           "2023-10-01"
#         ],
#         "temporal_extent_target": [
#           "2023-09-03",
#           "2023-09-29"
#         ]
#       },
#       "namespace": "https://raw.githubusercontent.com/bcdev/efast-process-graph/refs/heads/main/process_graph.json",
#       "result": true
#     }
#   }
# }

# %% [markdown]
# As a second example, we define a cube that computes the NDVI directly. Note that we set the bands to the red and nir bands of each collection.

# %%
ndvi_cube = connection.datacube_from_process(
    "efast",
    namespace=PROCESS_GRAPH_URL,
    s2_data_bands=["B04","B8A"],
    s3_data_bands=["Syn_Oa08_reflectance", "Syn_Oa17_reflectance"],
    temporal_extent=temporal_extent,
    temporal_extent_target=temporal_extent_target,
    spatial_extent=spatial_extent,
    interval_days=interval_days,
    output_ndvi=True,
)

# %% [markdown]
# ## Execute both parametrized process graphs
#
# Now, we just start the jobs, wait until they are complete, and download the results.
# Because EFAST fundamentally produces time series, `netcdf` is a good file format to choose. It is possible to generate `geotiff` output as well,
# but by default, each time step of the output will have its own file. In that case, we would need to use `download_files` instead of `download_file`.

# %%
out_path = Path("outputs_lite")
out_path.mkdir(exist_ok=True)

ndvi_cube_path = out_path / "efast_ndvi.nc"
bands_cube_path = out_path / "efast_with_bands.nc"

# %%
# %%time
def execute_jobs(bands_job, ndvi_job, wait_for_completion=True):
    bands_job.start()
    ndvi_job.start()

    if not wait_for_completion:
        return

    bands_status, ndvi_status = bands_job.status(), ndvi_job.status()
    incomplete_statuses = ["created", "queued", "running"]
    poll_interval = 40 # seconds
    
    while bands_status in incomplete_statuses or ndvi_status in incomplete_statuses:
        time_str = f"[{datetime.now().strftime('%Y-%m-%d | %H:%M:%S')}]"
        print(f"{time_str}\tbands: {bands_status}\tndvi: {ndvi_status}")
        time.sleep(poll_interval)
        bands_status, ndvi_status = bands_job.status(), ndvi_job.status()
    print(f"bands: {bands_status}\tndvi: {ndvi_status}")

if not SKIP_EXECUTION:
    ndvi_job = ndvi_cube.create_job(title="EFAST with NDVI", out_format="netcdf")
    bands_job = cube.create_job(title="EFAST with bands", out_format="netcdf")
    print(f"bands job id: {bands_job.job_id}")
    print(f"ndvi job id: {ndvi_job.job_id}")
    execute_jobs(bands_job, ndvi_job, WAIT_FOR_COMPLETION)
    if WAIT_FOR_COMPLETION:
        bands_job.get_results().download_file(bands_cube_path)
        ndvi_job.get_results().download_file(ndvi_cube_path)
# Out:
# bands job id: j-26012615540440a3b7c268c9324dd504
# ndvi job id: j-26012615540342c98ec16e45c2b6135d
# [2026-01-26 | 16:54:32]	bands: queued	ndvi: created
# [2026-01-26 | 16:55:13]	bands: running	ndvi: running
# [2026-01-26 | 16:55:53]	bands: running	ndvi: running
# [2026-01-26 | 16:56:33]	bands: running	ndvi: running
# [2026-01-26 | 16:57:13]	bands: running	ndvi: running
# [2026-01-26 | 16:57:53]	bands: running	ndvi: running
# [2026-01-26 | 16:58:34]	bands: running	ndvi: running
# [2026-01-26 | 16:59:14]	bands: running	ndvi: running
# [2026-01-26 | 16:59:54]	bands: running	ndvi: running
# [2026-01-26 | 17:00:34]	bands: running	ndvi: finished
# [2026-01-26 | 17:01:15]	bands: running	ndvi: finished
# bands: finished	ndvi: finished
# CPU times: user 558 ms, sys: 757 ms, total: 1.32 s
# Wall time: 8min 10s

# %% [markdown]
# ## Visualize results
#
# We can visualize EFAST results by generating time series animations for the NDVI and RGB results that we computed.

# %% [markdown]
# ### Bands

# %%
bands_ds = xr.open_dataset(bands_cube_path)
fig, ax = plt.subplots()
band_names = ["B04", "B03", "B02"]
bands_da = xr.concat(
    [bands_ds[b] for b in band_names], dim="band"
).coarsen(x=16, y=16, boundary="trim").mean()
p = bands_da.isel(t=0).plot.imshow(ax=ax)

def update(frame):
    data = bands_da.isel(t=frame).clip(0,1).transpose("y", "x", "band").values
    p.set_array(data)
    timestamp = pd.to_datetime(bands_da.t[frame].values)
    label = timestamp.strftime("%Y-%m-%d")
    ax.set_title(f"RGB @ {label}", fontsize=24)
    return (p,)

ani = animation.FuncAnimation(fig=fig, func=update, frames=len(bands_da.t), interval=600, blit=True)
plt.close(fig)
HTML(ani.to_jshtml()) # interactive animation
# Out:
# <link rel="stylesheet"
# href="https://maxcdn.bootstrapcdn.com/font-awesome/4.4.0/css/font-awesome.min.css">
# <script language="javascript">
#   function isInternetExplorer() {
#     ua = navigator.userAgent;
#     /* MSIE used to detect old browsers and Trident used to newer ones*/
#     return ua.indexOf("MSIE ") > -1 || ua.indexOf("Trident/") > -1;
#   }
#
#   /* Define the Animation class */
#   function Animation(frames, img_id, slider_id, interval, loop_select_id){
#     this.img_id = img_id;
#     this.slider_id = slider_id;
#     this.loop_select_id = loop_select_id;
#     this.interval = interval;
#     this.current_frame = 0;
#     this.direction = 0;
#     this.timer = null;
#     this.frames = new Array(frames.length);
#
#     for (var i=0; i<frames.length; i++)
#     {
#      this.frames[i] = new Image();
#      this.frames[i].src = frames[i];
#     }
#     var slider = document.getElementById(this.slider_id);
#     slider.max = this.frames.length - 1;
#     if (isInternetExplorer()) {
#         // switch from oninput to onchange because IE <= 11 does not conform
#         // with W3C specification. It ignores oninput and onchange behaves
#         // like oninput. In contrast, Microsoft Edge behaves correctly.
#         slider.setAttribute('onchange', slider.getAttribute('oninput'));
#         slider.setAttribute('oninput', null);
#     }
#     this.set_frame(this.current_frame);
#   }
#
#   Animation.prototype.get_loop_state = function(){
#     var button_group = document[this.loop_select_id].state;
#     for (var i = 0; i < button_group.length; i++) {
#         var button = button_group[i];
#         if (button.checked) {
#             return button.value;
#         }
#     }
#     return undefined;
#   }
#
#   Animation.prototype.set_frame = function(frame){
#     this.current_frame = frame;
#     document.getElementById(this.img_id).src =
#             this.frames[this.current_frame].src;
#     document.getElementById(this.slider_id).value = this.current_frame;
#   }
#
#   Animation.prototype.next_frame = function()
#   {
#     this.set_frame(Math.min(this.frames.length - 1, this.current_frame + 1));
#   }
#
#   Animation.prototype.previous_frame = function()
#   {
#     this.set_frame(Math.max(0, this.current_frame - 1));
#   }
#
#   Animation.prototype.first_frame = function()
#   {
#     this.set_frame(0);
#   }
#
#   Animation.prototype.last_frame = function()
#   {
#     this.set_frame(this.frames.length - 1);
#   }
#
#   Animation.prototype.slower = function()
#   {
#     this.interval /= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.faster = function()
#   {
#     this.interval *= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.anim_step_forward = function()
#   {
#     this.current_frame += 1;
#     if(this.current_frame < this.frames.length){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.first_frame();
#       }else if(loop_state == "reflect"){
#         this.last_frame();
#         this.reverse_animation();
#       }else{
#         this.pause_animation();
#         this.last_frame();
#       }
#     }
#   }
#
#   Animation.prototype.anim_step_reverse = function()
#   {
#     this.current_frame -= 1;
#     if(this.current_frame >= 0){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.last_frame();
#       }else if(loop_state == "reflect"){
#         this.first_frame();
#         this.play_animation();
#       }else{
#         this.pause_animation();
#         this.first_frame();
#       }
#     }
#   }
#
#   Animation.prototype.pause_animation = function()
#   {
#     this.direction = 0;
#     if (this.timer){
#       clearInterval(this.timer);
#       this.timer = null;
#     }
#   }
#
#   Animation.prototype.play_animation = function()
#   {
#     this.pause_animation();
#     this.direction = 1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_forward();
#     }, this.interval);
#   }
#
#   Animation.prototype.reverse_animation = function()
#   {
#     this.pause_animation();
#     this.direction = -1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_reverse();
#     }, this.interval);
#   }
# </script>
#
# <style>
# .animation {
#     display: inline-block;
#     text-align: center;
# }
# input[type=range].anim-slider {
#     width: 374px;
#     margin-left: auto;
#     margin-right: auto;
# }
# .anim-buttons {
#     margin: 8px 0px;
# }
# .anim-buttons button {
#     padding: 0;
#     width: 36px;
# }
# .anim-state label {
#     margin-right: 8px;
# }
# .anim-state input {
#     margin: 0;
#     vertical-align: middle;
# }
# </style>
#
# <div class="animation">
#   <img id="_anim_img4cd2527f9ebd4e78a103843f5cbe07cd">
#   <div class="anim-controls">
#     <input id="_anim_slider4cd2527f9ebd4e78a103843f5cbe07cd" type="range" class="anim-slider"
#            name="points" min="0" max="1" step="1" value="0"
#            oninput="anim4cd2527f9ebd4e78a103843f5cbe07cd.set_frame(parseInt(this.value));">
#     <div class="anim-buttons">
#       <button title="Decrease speed" aria-label="Decrease speed" onclick="anim4cd2527f9ebd4e78a103843f5cbe07cd.slower()">
#           <i class="fa fa-minus"></i></button>
#       <button title="First frame" aria-label="First frame" onclick="anim4cd2527f9ebd4e78a103843f5cbe07cd.first_frame()">
#         <i class="fa fa-fast-backward"></i></button>
#       <button title="Previous frame" aria-label="Previous frame" onclick="anim4cd2527f9ebd4e78a103843f5cbe07cd.previous_frame()">
#           <i class="fa fa-step-backward"></i></button>
#       <button title="Play backwards" aria-label="Play backwards" onclick="anim4cd2527f9ebd4e78a103843f5cbe07cd.reverse_animation()">
#           <i class="fa fa-play fa-flip-horizontal"></i></button>
#       <button title="Pause" aria-label="Pause" onclick="anim4cd2527f9ebd4e78a103843f5cbe07cd.pause_animation()">
#           <i class="fa fa-pause"></i></button>
#       <button title="Play" aria-label="Play" onclick="anim4cd2527f9ebd4e78a103843f5cbe07cd.play_animation()">
#           <i class="fa fa-play"></i></button>
#       <button title="Next frame" aria-label="Next frame" onclick="anim4cd2527f9ebd4e78a103843f5cbe07cd.next_frame()">
#           <i class="fa fa-step-forward"></i></button>
#       <button title="Last frame" aria-label="Last frame" onclick="anim4cd2527f9ebd4e78a103843f5cbe07cd.last_frame()">
#           <i class="fa fa-fast-forward"></i></button>
#       <button title="Increase speed" aria-label="Increase speed" onclick="anim4cd2527f9ebd4e78a103843f5cbe07cd.faster()">
#           <i class="fa fa-plus"></i></button>
#     </div>
#     <form title="Repetition mode" aria-label="Repetition mode" action="#n" name="_anim_loop_select4cd2527f9ebd4e78a103843f5cbe07cd"
#           class="anim-state">
#       <input type="radio" name="state" value="once" id="_anim_radio1_4cd2527f9ebd4e78a103843f5cbe07cd"
#              >
#       <label for="_anim_radio1_4cd2527f9ebd4e78a103843f5cbe07cd">Once</label>
#       <input type="radio" name="state" value="loop" id="_anim_radio2_4cd2527f9ebd4e78a103843f5cbe07cd"
#              checked>
#       <label for="_anim_radio2_4cd2527f9ebd4e78a103843f5cbe07cd">Loop</label>
#       <input type="radio" name="state" value="reflect" id="_anim_radio3_4cd2527f9ebd4e78a103843f5cbe07cd"
#              >
#       <label for="_anim_radio3_4cd2527f9ebd4e78a103843f5cbe07cd">Reflect</label>
#     </form>
#   </div>
# </div>
#
#
# <script language="javascript">
#   /* Instantiate the Animation class. */
#   /* The IDs given should match those used in the template above. */
#   (function() {
#     var img_id = "_anim_img4cd2527f9ebd4e78a103843f5cbe07cd";
#     var slider_id = "_anim_slider4cd2527f9ebd4e78a103843f5cbe07cd";
#     var loop_select_id = "_anim_loop_select4cd2527f9ebd4e78a103843f5cbe07cd";
#     var frames = new Array(3);
#
#   frames[0] = "...\
# bGliIHZlcnNpb24zLjEwLjgsIGh0dHBzOi8vbWF0cGxvdGxpYi5vcmcvwVt1zgAAAAlwSFlzAAAP\
# YQAAD2EBqD+naQABAABJRE

# %% [markdown]
# ### NDVI

# %%
ndvi_da = xr.open_dataset(ndvi_cube_path)["ndvi"]
fig, ax = plt.subplots()
imshow_args = dict(cmap="RdYlGn", vmin=-1, vmax=1)

p = ndvi_da.isel(t=0).plot.imshow(ax=ax, **imshow_args)

def update(frame):
    data = ndvi_da.isel(t=frame).values
    p.set_array(data)
    timestamp = pd.to_datetime(ndvi_da.t[frame].values)
    label = timestamp.strftime("NDVI @ %Y-%m-%d")
    ax.set_title(label, fontsize=20)
    return (p,)

ani = animation.FuncAnimation(fig=fig, func=update, frames=len(ndvi_da.t), interval=600, blit=True)
plt.close(fig)
#ani.save(ndvi_animation_path, writer="pillow")
HTML(ani.to_jshtml()) # interactive animation
# Out:
# <link rel="stylesheet"
# href="https://maxcdn.bootstrapcdn.com/font-awesome/4.4.0/css/font-awesome.min.css">
# <script language="javascript">
#   function isInternetExplorer() {
#     ua = navigator.userAgent;
#     /* MSIE used to detect old browsers and Trident used to newer ones*/
#     return ua.indexOf("MSIE ") > -1 || ua.indexOf("Trident/") > -1;
#   }
#
#   /* Define the Animation class */
#   function Animation(frames, img_id, slider_id, interval, loop_select_id){
#     this.img_id = img_id;
#     this.slider_id = slider_id;
#     this.loop_select_id = loop_select_id;
#     this.interval = interval;
#     this.current_frame = 0;
#     this.direction = 0;
#     this.timer = null;
#     this.frames = new Array(frames.length);
#
#     for (var i=0; i<frames.length; i++)
#     {
#      this.frames[i] = new Image();
#      this.frames[i].src = frames[i];
#     }
#     var slider = document.getElementById(this.slider_id);
#     slider.max = this.frames.length - 1;
#     if (isInternetExplorer()) {
#         // switch from oninput to onchange because IE <= 11 does not conform
#         // with W3C specification. It ignores oninput and onchange behaves
#         // like oninput. In contrast, Microsoft Edge behaves correctly.
#         slider.setAttribute('onchange', slider.getAttribute('oninput'));
#         slider.setAttribute('oninput', null);
#     }
#     this.set_frame(this.current_frame);
#   }
#
#   Animation.prototype.get_loop_state = function(){
#     var button_group = document[this.loop_select_id].state;
#     for (var i = 0; i < button_group.length; i++) {
#         var button = button_group[i];
#         if (button.checked) {
#             return button.value;
#         }
#     }
#     return undefined;
#   }
#
#   Animation.prototype.set_frame = function(frame){
#     this.current_frame = frame;
#     document.getElementById(this.img_id).src =
#             this.frames[this.current_frame].src;
#     document.getElementById(this.slider_id).value = this.current_frame;
#   }
#
#   Animation.prototype.next_frame = function()
#   {
#     this.set_frame(Math.min(this.frames.length - 1, this.current_frame + 1));
#   }
#
#   Animation.prototype.previous_frame = function()
#   {
#     this.set_frame(Math.max(0, this.current_frame - 1));
#   }
#
#   Animation.prototype.first_frame = function()
#   {
#     this.set_frame(0);
#   }
#
#   Animation.prototype.last_frame = function()
#   {
#     this.set_frame(this.frames.length - 1);
#   }
#
#   Animation.prototype.slower = function()
#   {
#     this.interval /= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.faster = function()
#   {
#     this.interval *= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.anim_step_forward = function()
#   {
#     this.current_frame += 1;
#     if(this.current_frame < this.frames.length){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.first_frame();
#       }else if(loop_state == "reflect"){
#         this.last_frame();
#         this.reverse_animation();
#       }else{
#         this.pause_animation();
#         this.last_frame();
#       }
#     }
#   }
#
#   Animation.prototype.anim_step_reverse = function()
#   {
#     this.current_frame -= 1;
#     if(this.current_frame >= 0){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.last_frame();
#       }else if(loop_state == "reflect"){
#         this.first_frame();
#         this.play_animation();
#       }else{
#         this.pause_animation();
#         this.first_frame();
#       }
#     }
#   }
#
#   Animation.prototype.pause_animation = function()
#   {
#     this.direction = 0;
#     if (this.timer){
#       clearInterval(this.timer);
#       this.timer = null;
#     }
#   }
#
#   Animation.prototype.play_animation = function()
#   {
#     this.pause_animation();
#     this.direction = 1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_forward();
#     }, this.interval);
#   }
#
#   Animation.prototype.reverse_animation = function()
#   {
#     this.pause_animation();
#     this.direction = -1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_reverse();
#     }, this.interval);
#   }
# </script>
#
# <style>
# .animation {
#     display: inline-block;
#     text-align: center;
# }
# input[type=range].anim-slider {
#     width: 374px;
#     margin-left: auto;
#     margin-right: auto;
# }
# .anim-buttons {
#     margin: 8px 0px;
# }
# .anim-buttons button {
#     padding: 0;
#     width: 36px;
# }
# .anim-state label {
#     margin-right: 8px;
# }
# .anim-state input {
#     margin: 0;
#     vertical-align: middle;
# }
# </style>
#
# <div class="animation">
#   <img id="_anim_img5f003ef8fff9489988043d391b7b3ead">
#   <div class="anim-controls">
#     <input id="_anim_slider5f003ef8fff9489988043d391b7b3ead" type="range" class="anim-slider"
#            name="points" min="0" max="1" step="1" value="0"
#            oninput="anim5f003ef8fff9489988043d391b7b3ead.set_frame(parseInt(this.value));">
#     <div class="anim-buttons">
#       <button title="Decrease speed" aria-label="Decrease speed" onclick="anim5f003ef8fff9489988043d391b7b3ead.slower()">
#           <i class="fa fa-minus"></i></button>
#       <button title="First frame" aria-label="First frame" onclick="anim5f003ef8fff9489988043d391b7b3ead.first_frame()">
#         <i class="fa fa-fast-backward"></i></button>
#       <button title="Previous frame" aria-label="Previous frame" onclick="anim5f003ef8fff9489988043d391b7b3ead.previous_frame()">
#           <i class="fa fa-step-backward"></i></button>
#       <button title="Play backwards" aria-label="Play backwards" onclick="anim5f003ef8fff9489988043d391b7b3ead.reverse_animation()">
#           <i class="fa fa-play fa-flip-horizontal"></i></button>
#       <button title="Pause" aria-label="Pause" onclick="anim5f003ef8fff9489988043d391b7b3ead.pause_animation()">
#           <i class="fa fa-pause"></i></button>
#       <button title="Play" aria-label="Play" onclick="anim5f003ef8fff9489988043d391b7b3ead.play_animation()">
#           <i class="fa fa-play"></i></button>
#       <button title="Next frame" aria-label="Next frame" onclick="anim5f003ef8fff9489988043d391b7b3ead.next_frame()">
#           <i class="fa fa-step-forward"></i></button>
#       <button title="Last frame" aria-label="Last frame" onclick="anim5f003ef8fff9489988043d391b7b3ead.last_frame()">
#           <i class="fa fa-fast-forward"></i></button>
#       <button title="Increase speed" aria-label="Increase speed" onclick="anim5f003ef8fff9489988043d391b7b3ead.faster()">
#           <i class="fa fa-plus"></i></button>
#     </div>
#     <form title="Repetition mode" aria-label="Repetition mode" action="#n" name="_anim_loop_select5f003ef8fff9489988043d391b7b3ead"
#           class="anim-state">
#       <input type="radio" name="state" value="once" id="_anim_radio1_5f003ef8fff9489988043d391b7b3ead"
#              >
#       <label for="_anim_radio1_5f003ef8fff9489988043d391b7b3ead">Once</label>
#       <input type="radio" name="state" value="loop" id="_anim_radio2_5f003ef8fff9489988043d391b7b3ead"
#              checked>
#       <label for="_anim_radio2_5f003ef8fff9489988043d391b7b3ead">Loop</label>
#       <input type="radio" name="state" value="reflect" id="_anim_radio3_5f003ef8fff9489988043d391b7b3ead"
#              >
#       <label for="_anim_radio3_5f003ef8fff9489988043d391b7b3ead">Reflect</label>
#     </form>
#   </div>
# </div>
#
#
# <script language="javascript">
#   /* Instantiate the Animation class. */
#   /* The IDs given should match those used in the template above. */
#   (function() {
#     var img_id = "_anim_img5f003ef8fff9489988043d391b7b3ead";
#     var slider_id = "_anim_slider5f003ef8fff9489988043d391b7b3ead";
#     var loop_select_id = "_anim_loop_select5f003ef8fff9489988043d391b7b3ead";
#     var frames = new Array(3);
#
#   frames[0] = "...\
# bGliIHZlcnNpb24zLjEwLjgsIGh0dHBzOi8vbWF0cGxvdGxpYi5vcmcvwVt1zgAAAAlwSFlzAAAP\
# YQAAD2EBqD+naQABAABJRE
